# %%
import requests
from bs4 import BeautifulSoup

# %%
header = {
    "Content-Type": "text/html; charset=utf-8",
    "Content-Encoding": "gzip",
    "Content-Security-Policy": "base-uri 'self'; child-src https://*.craigslist.org; connect-src https://*.craigslist.org; font-src data:; form-action https://*.craigslist.org; frame-ancestors 'self'; frame-src https://*.craigslist.org https://craigslist.org https://hcaptcha.com https://*.hcaptcha.com; media-src data:; object-src 'none'; script-src 'unsafe-inline' 'unsafe-eval' https://*.craigslist.org https://hcaptcha.com https://*.hcaptcha.com; style-src 'unsafe-inline' https://*.craigslist.org"
}

url = "https://providence.craigslist.org/search/sss?purveyor=owner"

# %%
r = requests.get(url, headers = header)

# %%
r
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.text)

# %%
import json

# %%
data = json.loads(soup.find(id="ld_searchpage_results").text.strip())

# %%
data.keys()
# Out:
# dict_keys(['itemListElement', '@type', '@context'])

# %%
len(data["itemListElement"])
# Out:
# 279

# %%
data["itemListElement"][0]
# Out:
# {'@type': 'ListItem',
#  'item': {'offers': {'availableAtOrFrom': {'geo': {'@type': 'GeoCoordinates',
#      'latitude': 41.6942991776096,
#      'longitude': -71.4996020668839},
#     'address': {'addressRegion': 'RI',
#      '@type': 'PostalAddress',
#      'addressCountry': '',
#      'postalCode': '',
#      'streetAddress': '',
#      'addressLocality': 'West Warwick'},
#     '@type': 'Place'},
#    'price': '300.00',
#    '@type': 'Offer',
#    'priceCurrency': 'USD'},
#   '@type': 'Product',
#   '@context': 'http://schema.org',
#   'name': 'TDS plate loaded Pec Deck machine',
#   'description': '',
#   'image': ['https://images.craigslist.org/00v0v_2IwK3FLDeIO_0t20CI_600x450.jpg',
#    'https://images.craigslist.org/00505_kFPF1ATfeBY_0t20CI_600x450.jpg',
#    'https://images.craigslist.org/01414_iqqKNEqSYUI_0t20CI_600x450.jpg']},
#  'position': '0'}

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="craigslist" property="og:site_name"/>
# <meta content="preview" name="twitter:card"/>
# <meta content="rhode island for sale by owner - craigslist" property="og:title"/>
# <meta content="rhode island for sale by owner - craigslist" name="description"/>
# <meta content="rhode island for sale by owner - craigslist" property="og:description"/>
# <meta content="https://providence.craigslist.org/search/sss?purveyor=owner" property="og:url"/>
# <title>rhode island for sale by owner - craigslist</title>
# <link href="https://providence.craigslist.org/search/sss?purveyor=owner" rel="canonical"/>
# <link href="https://providence.craigslist.org/search/sss?purveyor=owner" hreflang="x-default" rel="alternate"/>
# <link href="/favicon.ico" id="favicon" rel="icon">
# ...

# %%
import httpx

# %%
cli = httpx.Client()

# %%
r = cli.get("https://providence.craigslist.org/search/sss#search=1~gallery~0~29")

# %%
r
# Out:
# <Response [200 OK]>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text)

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="craigslist" property="og:site_name"/>
# <meta content="preview" name="twitter:card"/>
# <meta content="rhode island for sale - craigslist" property="og:title"/>
# <meta content="rhode island for sale - craigslist" name="description"/>
# <meta content="rhode island for sale - craigslist" property="og:description"/>
# <meta content="https://providence.craigslist.org/search/sss" property="og:url"/>
# <title>rhode island for sale - craigslist</title>
# <link href="https://providence.craigslist.org/search/sss" rel="canonical"/>
# <link href="https://providence.craigslist.org/search/sss" hreflang="x-default" rel="alternate"/>
# <link href="/favicon.ico" id="favicon" rel="icon">
# <script id="ld_searchpage_data" type="application/ld+json">
# ...
